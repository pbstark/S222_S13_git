# %%
# %pylab inline
import networkx as nx
import matplotlib.pyplot as plt
DG=nx.DiGraph()
DG.add_weighted_edges_from([(1,2,4), (2,1,3), (1,3,1), (3,4,1), (1,4,1), (1,4,1)])
nx.draw(DG)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import scipy.sparse
A=scipy.sparse.eye(2,2,1)
DG=nx.from_scipy_sparse_matrix(A, create_using=nx.DiGraph())
nx.draw(DG)

# %%
DG = nx.DiGraph()
DG.add_weighted_edges_from([(1,2,4), (2,1,3), (1,3,1), (3,4,1), (1,4,1), (1,4,1), (2,5,1), (3,5,1), (5,1,1)])
print nx.simple_cycles(DG)
print DG.order()
print DG.size()
nx.draw_spectral(DG)
# Out:
# [[1, 2, 1], [1, 2, 5, 1], [1, 3, 5, 1]]
# 5
# 8
